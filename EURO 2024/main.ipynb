# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
data = pd.read_excel('nodes - words - text_filtered_data - comments_data - original_data - edgelist.xlsx', sheet_name='')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data.head
# Out:
#            Id       Label
# 0       meant       meant
# 1  discussion  discussion
# 2     current     current
# 3         war         war
# 4        also        also
