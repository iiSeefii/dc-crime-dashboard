# %%
password = 'Jalil$$1965'
user = input('Enter the password :')

if user == password:
    print('Access granted ')
else:
    print('Access Denied')

# %%
N1 = int(input('Enter the first number :'))
sign = input('Enter the sign')
N2 = int(input('Enter the second number'))


if sign == '+':
    print(N1+N2)
elif sign == '-':
    print(N1-N2)
elif sign == '*':
    print(N1*N2)
elif sign == '/':
    print(N1/N2)
else:
    print('Denied Operation!!!')

# %%
for i in range(10,100,10):
    print(i)

# %%
c = 0 
while c < 10:
    print('seif')
    c=c+1

# %%
def calc():
    N1 = int(input('Enter the first number :'))
    sign = input('Enter the sign')
    N2 = int(input('Enter the second number'))


    if sign == '+':
        print(N1+N2)
    elif sign == '-':
        print(N1-N2)
    elif sign == '*':
        print(N1*N2)
    elif sign == '/':
        print(N1/N2)
    else:
        print('Denied Operation!!!')

# %%
calc()

# %%
def calc2(n1,n2):
    print(n1+n2)

# %%
calc2(10,23)

# %%
x = [1,2,3,4,5.5,'seif',True]
x[3:6]

# %%
z = {
    'emp_name':'Seif',
    'emp_sal':10000,
    'emp_dep':'ML Eng'
    }

# %%
z['emp_name']
# Out:
# <function dict.keys>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])
